# %% [markdown]
# ## Forward prop using Numpy

# %% [markdown]
# Here you'll get the idea of how you can make a simple neural network through hard  coding and defining functions using Numpy.

# %% [markdown]
# ![Screenshot 2025-04-22 100907.png](<attachment:Screenshot 2025-04-22 100907.png>)

# %% [markdown]
# ![Screenshot 2025-04-22 102818.png](<attachment:Screenshot 2025-04-22 102818.png>)

# %% [markdown]
# Above are the fairly simple and familiar functions which make up a layer in a neural network
